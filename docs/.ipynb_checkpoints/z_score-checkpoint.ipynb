# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import itertools

from sklearn.decomposition import PCA
from scipy.spatial.distance import mahalanobis

from context import predicate_search
from predicate_search import RobustNormal

# %%
raw_data = pd.read_csv('../data/breast_cancer.csv')
benign = raw_data[raw_data.diagnosis=='B']
malignant = raw_data[raw_data.diagnosis=='M']
df = pd.concat([benign, malignant.iloc[:10]])
y = (df.diagnosis == 'M').values.astype(int)
df = df.drop(['id', 'diagnosis', 'Unnamed: 32'], axis=1).reset_index(drop=True)
df.columns = [c.replace(' ', '_') for c in df.columns]

# %%
max_vals = df.max()
df = df / max_vals

# %%
df.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0     0.658240      0.424726        0.647372   0.427074         0.598470
# 1     0.635877      0.464655        0.633827   0.392157         0.657895
# 2     0.462032      0.367938        0.446632   0.206561         0.626683
# 3     0.633447      0.544809        0.611473   0.395023         0.549755
# 4     0.398444      0.498077        0.382754   0.152262         0.526316
#
#    compactness_mean  concavity_mean  concave_points_mean  symmetry_mean  \
# 0          0.286333        0.162220             0.325017       0.687204
# 1          0.447341        0.111198             0.211421       0.717098
# 2          0.228672        0.071957             0.141128       0.661684
# 3          0.132652        0.062366             0.198708       0.534816
# 4          0.209334        0.038656             0.040224       0.644914
#
#    fractal_dimension_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0                0.591749  ...      0.595351       0.460986         0.540087
# 1                0.698994  ...      0.571316       0.490426         0.520531
# 2                0.708641  ...      0.403073       0.374820         0.352817
# 3                0.601704  ...      0.524035       0.545955         0.457530
# 4                0.667385  ...      0.353191       0.525610         0.310184
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0    0.352254          0.686368           0.167580         0.190895
# 1    0.312283          0.625357           0.262382         0.150958
# 2    0.155968          0.631077           0.108507         0.070823
# 3    0.270381          0.462393           0.043658         0.038602
# 4    0.119960          0.618208           0.128261         0.054952
#
#    concave_points_worst  symmetry_worst  fractal_dimension_worst
# 0              0.485305        0.448478                 0.349831
# 1              0.274416        0.479663                 0.394361
# 2              0.234627        0.369087                 0.374602
# 3              0.188885        0.299337                 0.297301
# 4              0.096609        0.467761                 0.357060
#
# [5 rows x 30 columns]

# %%
model = RobustNormal()
model.fit(df)
# Out:
# /Users/bmontambault/anaconda3/envs/forecasting/lib/python3.7/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
# /Users/bmontambault/anaconda3/envs/forecasting/lib/python3.7/site-packages/theano/tensor/subtensor.py:2339: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   out[0][inputs[2:]] = inputs[1]
# /Users/bmontambault/anaconda3/envs/forecasting/lib/python3.7/site-packages/pymc3/tuning/starting.py:61: UserWarning: find_MAP should not be used to initialize the NUTS sampler, simply call pymc3.sample() and it will automatically initialize NUTS in a better way.
#   warnings.warn('find_MAP should not be used to initialize the NUTS sampler, simply call pymc3.sample() and it will automatically initialize NUTS in a better way.')
# /Users/bmontambault/anaconda3/envs/forecasting/lib/python3.7/site-packages/theano/tensor/basic.py:6611: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result[diagonal_slice] = x
# /Users/bmontambault/anaconda3/envs/forecasting/lib/python3.7/site-packages/theano/tensor/subtensor.py:2339: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   out[0][inputs[2:]] = inputs[1]
# /Users/bmontambault/anaconda3/envs/forecasting/lib/python3.7/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
#   0%|          | 0/5000 [00:00<?, ?it/s]/Users/bmontambault/anaconda3/envs/forecasting/lib/python3.7/site-packages/theano/tensor/subtensor.py:2339: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   out[0][inputs[2:]] = inputs[1]
# /Users/bmontambault/anaconda3/envs/forecasting/lib/python3.7/site-packages/theano/tensor/basic.py:6611: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result[diagonal_slice] = x
# /Users/bmontambault/anaconda3/envs/forecasting/lib/python3.7/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
# logp = 24,076, ||grad|| = 1,400: : 5001it [00:08, 585.99it/s]
#
# /Users/bmontambault/anaconda3/envs/forecasting/lib/python3.7/site-packages/theano/tensor/subtensor.py:2339: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   out[0][inputs[2:]] = inputs[1]

# %%
mean = pd.Series(model.mean, index=df.columns)
cov = pd.DataFrame(model.cov, index=df.columns, columns=df.columns)

# %%
def get_z_scores(df, mean, cov, k=2):
    res = {}
    for n in range(2, k+1):
        for group in itertools.combinations(df.columns, n):
            features = list(group)
            m = mean[features].values
            c = cov[features].loc[features].values
            prec = np.linalg.inv(c)
            x = df[features].values
            
            VI = np.linalg.inv(c)
            dist = np.diag(np.sqrt(np.dot(np.dot((x-m),VI),(x-m).T)))
            res[group] = dist.tolist()
    return res

# %%
a = get_z_scores(df, mean, cov)

# %%
a[('radius_mean', 'texture_mean')]
# Out:
# [1.5340617577997024,
#  0.9398521503683417,
#  3.053150118625497,
#  0.6924806645419308,
#  3.776371805650608,
#  0.9923265890303632,
#  1.791128356094711,
#  1.3115608772614151,
#  1.2875822877157872,
#  0.3776050408438761,
#  0.7929558952761848,
#  0.8386019748865253,
#  3.854650361922791,
#  2.1516178874130807,
#  3.5459379799868276,
#  3.115472164999517,
#  2.7987945291835388,
#  1.005139691576255,
#  3.0065589050516626,
#  0.5733919104528,
#  3.2779221211150524,
#  0.3731227085740471,
#  2.3873190587073028,
#  0.5088266403990418,
#  1.284337288908346,
#  1.103324028400488,
#  0.7053510200643436,
#  1.274194692019637,
#  2.264078803717129,
#  2.8867186817282584,
#  1.2708500600629864,
#  1.0567906648096137,
#  0.12708330301981174,
#  2.4112898401980023,
#  1.6553653674765147,
#  5.059402257763808,
#  0.8824132615771701,
#  2.289282230294082,
#  1.7373191748471013,
#  0.6439902585315874,
#  0.26052252865422076,
#  1.4176021236352296,
#  2.331002175287957,
#  0.9929629668227309,
#  1.8818917961182424,
#  1.8194593609442027,
#  3.3343530327243447,
#  1.2390950789841721,
#  3.137046557323793,
#  2.3047666834072795,
#  2.919655271912072,
#  1.0516957224087136,
#  1.4152969091899985,
#  2.5830169453608725,
#  1.3850499782592898,
#  3.323445862452762,
#  0.6409432971660843,
#  1.0862106492192714,
#  1.6480971948018273,
#  2.961621926255828,
#  0.8174046440317826,
#  0.7758263811146593,
#  1.6674796243228378,
#  1.0285247077687916,
#  2.435807321115874,
#  2.0999558700480936,
#  1.3075366438063634,
#  1.1445968406656004,
#  3.8575095197870457,
#  2.4763083450924452,
#  1.7961141360355073,
#  1.0652156002257358,
#  0.09004818261309767,
#  4.178523668504505,
#  1.5692875949382536,
#  1.9686445913853277,
#  0.9239850903544984,
#  1.4046221578802125,
#  2.5143981404802633,
#  2.8563157434292923,
#  2.4427275193437614,
#  1.6610037338439927,
#  1.4674674529423912,
#  1.7116158790315341,
#  3.4851839211589084,
#  2.2058826747174023,
#  1.5434291273240304,
#  1.521103335309459,
#  1.2017792069103717,
#  2.199333483564729,
#  0.5753278822194094,
#  0.47096005233009175,
#  0.5665828748849103,
#  1.226070626560494,
#  2.3767365681307258,
#  0.6965018538534886,
#  0.5796868517490118,
#  0.31113124882942644,
#  2.233607505753303,
#  1.672767030221769,
#  3.091271889043086,
#  0.5761034628424911,
#  0.43378096998619353,
#  1.9341504235028617,
#  1.8738245153068829,
#  1.6477543409098592,
#  1.9518849685740605,
#  0.9022670348210003,
#  2.277543588742743,
#  1.8529180554555078,
#  2.552280800162704,
#  1.9706837523262963,
#  3.0565090547338607,
#  5.115644736332474,
#  2.5749698527354816,
#  1.920543316191023,
#  3.6121637814406182,
#  1.3814442121240254,
#  0.8402674828525796,
#  0.9377402627293522,
#  2.3022981766050816,
#  1.8038836463056633,
#  0.8167845967896613,
#  1.2418762069610685,
#  2.788843648900974,
#  1.132487120289366,
#  0.777358447354687,
#  1.6126537904090363,
#  1.738979874502675,
#  0.6929571272926329,
#  1.6854368414471579,
#  1.8303001607426388,
#  1.733697552319679,
#  2.437620357965085,
#  0.4023107865794795,
#  1.4285737422682137,
#  1.1695128513626767,
#  1.6127956612856373,
#  1.2668074769636657,
#  0.820752334203215,
#  0.3248165989381078,
#  1.007911250151916,
#  1.5269161895684296,
#  1.1893443610717707,
#  0.9361613389058047,
#  2.0200206431931678,
#  2.460964902804573,
#  0.7868862459639857,
#  0.43068771096629355,
#  1.2823968850234213,
#  1.922325360374228,
#  2.110251313454161,
#  1.7876062806521098,
#  2.3492279222729855,
#  0.6912893938273531,
#  1.6900295281423867,
#  0.7918460068509726,
#  2.209581864477505,
#  1.0038399992992924,
#  3.203561440312606,
#  1.90073103019575,
#  1.383542987098696,
#  0.7085555873920099,
#  2.19403918414081,
#  1.4153162832916533,
#  2.2943642072323107,
#  3.4099309611750197,
#  0.31507260744858817,
#  1.1406289573998183,
#  3.0141995622036486,
#  0.24782706692975776,
#  1.947464024116735,
#  1.458948496514965,
#  0.7885108879215224,
#  0.3517887689986132,
#  2.2297683066732867,
#  0.2667404527755183,
#  0.7958679617873955,
#  1.201543909072595,
#  1.336401007914178,
#  0.40662212577177675,
#  1.250722265055724,
#  2.070770066336382,
#  1.9622311509063077,
#  2.491519133237122,
#  1.433436974742424,
#  0.8969235183137695,
#  2.1000300755010946,
#  0.43507407098338874,
#  2.4227078910872066,
#  0.9337119672590061,
#  0.921777427540896,
#  0.6303142278658381,
#  1.5643592642147224,
#  0.47929859129129676,
#  0.7280636732119152,
#  1.4997654897037913,
#  3.2189139262941753,
#  2.6380465942491913,
#  0.23572120026099078,
#  1.504509314460578,
#  0.5392914505235173,
#  3.8355702137643197,
#  1.0229546565682848,
#  0.13309378173489836,
#  2.9823832844356586,
#  1.360174727778258,
#  3.565617781845526,
#  1.7739805716975523,
#  3.438049007342885,
#  1.4688578140004238,
#  1.7645981980857945,
#  1.4537049836352713,
#  1.578289228381122,
#  0.10226841987667795,
#  1.527568325541835,
#  1.134892269789324,
#  1.5133629916524143,
#  1.1786688199580873,
#  2.5442727473490803,
#  3.2856484650503184,
#  0.19435674646733767,
#  1.6072983877345168,
#  1.1556435585963276,
#  0.4530607112210076,
#  1.4581549061896844,
#  0.4901587293043301,
#  2.1516769344190054,
#  0.619103497874154,
#  0.7492606374240418,
#  0.8630278190743205,
#  1.284430255989851,
#  3.612008047750056,
#  1.2415871748189913,
#  0.07434456599788437,
#  0.8726337707128657,
#  1.1969049542885457,
#  2.938063656465816,
#  2.808534286250993,
#  1.1436372461942927,
#  2.9340519386046626,
#  1.765057500421641,
#  1.560322819214314,
#  0.7942750436706905,
#  2.466083346643139,
#  0.8329959909710708,
#  1.309907215983597,
#  2.3913906421728193,
#  2.3639717732661265,
#  1.882282935791625,
#  1.9174932088906975,
#  1.1350289644614462,
#  0.3731328188153752,
#  0.08089752521712278,
#  2.342909582820782,
#  0.7644710508024207,
#  1.6699464637529016,
#  1.5251925016825438,
#  1.6878420690587204,
#  1.2389272967249638,
#  1.4701061885340438,
#  1.6049193383551914,
#  2.2558948008629827,
#  2.275872458959682,
#  2.0917553341691684,
#  1.258574923709792,
#  3.290512521966941,
#  2.338094614060725,
#  0.33201853098701334,
#  4.172352169105325,
#  3.6617376970340887,
#  2.489760519902152,
#  2.3967593448518043,
#  4.01733850575339,
#  3.4679517502593757,
#  0.681702103304468,
#  0.8003555688496036,
#  1.1351113126414711,
#  1.2100852301822722,
#  2.4221284727363335,
#  0.6495690875847581,
#  2.4318998193987955,
#  3.259606093610365,
#  2.53772429174053,
#  3.821234656670466,
#  1.4654023805157188,
#  0.7791498181362415,
#  1.9381541944873295,
#  1.4916454022674033,
#  1.232429839511711,
#  0.1701952225053161,
#  1.5288314762281385,
#  1.5550214496727073,
#  1.2696471287485096,
#  3.7129522815943528,
#  0.4262317390214849,
#  2.1461251530092094,
#  0.7537811935518937,
#  1.4739847279384584,
#  5.253847458270144,
#  1.5295599852052282,
#  1.1741126479895474,
#  2.4667841385972005,
#  0.33986096602907095,
#  0.19181711403337195,
#  2.513463477509623,
#  0.4824082759096328,
#  3.1708883584052803,
#  2.8044289687811914,
#  0.7293473442754261,
#  1.1611073073252576,
#  3.7010309452719587,
#  1.0800261378924467,
#  2.4697307185019595,
#  2.4281919507831238,
#  0.9318811341479809,
#  0.5426964035177501,
#  0.5102503847791636,
#  3.007840971241153,
#  1.1660090425932705,
#  1.313869453748915,
#  2.3441917821348315,
#  3.715357886317341,
#  1.0986969536066087,
#  1.6985697391037853,
#  2.0545057578966954,
#  1.352215575735154,
#  0.5169459013658643,
#  0.927458501807671,
#  1.3231518108993585,
#  1.2377332484329595,
#  2.171776767099855,
#  4.840424978959525,
#  4.862826914881329,
#  1.2431809536476148,
#  3.00901402584966,
#  3.274015428497834,
#  3.329557869429603,
#  1.702973257373306,
#  2.09599978025951,
#  1.8726101591631559,
#  1.9114112183663508,
#  2.4575871520431014,
#  2.440570718628313,
#  1.771562425622961,
#  1.8262400056058716,
#  3.677231234905607,
#  3.025577370343762,
#  3.532807080634078,
#  3.5951103458302947,
#  2.05323240188886,
#  4.1240727839581055,
#  2.5975211723890315,
#  2.0709941641984893,
#  3.345839469783016,
#  3.7723623629913856,
#  4.674191186290262,
#  5.672696588980835,
#  7.554752195975569,
#  6.840578290035917,
#  1.1638195265436628,
#  7.372549168023592,
#  0.6411062449265597,
#  5.478885855189822,
#  1.6066070151279344,
#  1.4267172815118725,
#  1.9767179518194575]

# %%
for i in range(1, 4):
    for j in itertools.combinations(df.columns, i):
        print(j)
# Out:
# ('radius_mean',)
# ('texture_mean',)
# ('perimeter_mean',)
# ('area_mean',)
# ('smoothness_mean',)
# ('compactness_mean',)
# ('concavity_mean',)
# ('concave_points_mean',)
# ('symmetry_mean',)
# ('fractal_dimension_mean',)
# ('radius_se',)
# ('texture_se',)
# ('perimeter_se',)
# ('area_se',)
# ('smoothness_se',)
# ('compactness_se',)
# ('concavity_se',)
# ('concave_points_se',)
# ('symmetry_se',)
# ('fractal_dimension_se',)
# ('radius_worst',)
# ('texture_worst',)
# ('perimeter_worst',)
# ('area_worst',)
# ('smoothness_worst',)
# ('compactness_worst',)
# ('concavity_worst',)
# ('concave_points_worst',)
# ('symmetry_worst',)
# ('fractal_dimension_worst',)
# ('radius_mean', 'texture_mean')
# ('radius_mean', 'perimeter_mean')
# ('radius_mean', 'area_mean')
# ('radius_mean', 'smoothness_mean')
# ('radius_mean', 'compactness_mean')
# ('radius_mean', 'concavity_mean')
# ('radius_mean', 'concave_points_mean')
# ('radius_mean', 'symmetry_mean')
# ('radius_mean', 'fractal_dimension_mean')
# ('radius_mean', 'radius_se')
# ('radius_mean', 'texture_se')
# ('radius_mean', 'perimeter_se')
# ('radius_mean', 'area_se')
# ('radius_mean', 'smoothness_se')
# ('radius_mean', 'compactness_se')
# ('radius_mean', 'concavity_se')
# ('radius_mean', 'concave_points_se')
# ('radius_mean', 'symmetry_se')
# ('radius_mean', 'fractal_dimension_se')
# ('radius_mean', 'radius_worst')
# ('radius_mean', 'texture_worst')
# ('radius_mean', 'perimeter_worst')
# ('radius_mean', 'area_worst')
# ('radius_mean', 'smoothness_worst')
# ('radius_mean', 'compactness_worst')
# ('radius_mean', 'concavity_worst')
# ('radius_mean', 'concave_points_worst')
# ('radius_mean', 'symmetry_worst')
# ('radius_mean', 'fractal_dimension_worst')
# ('texture_mean', 'perimeter_mean')
# ('texture_mean', 'area_mean')
# ('texture_mean', 'smoothness_mean')
# ('texture_mean', 'compactness_mean')
# ('texture_mean', 'concavity_mean')
# ('texture_mean', 'concave_points_mean')
# ('texture_mean', 'symmetry_mean')
# ('texture_mean', 'fractal_dimension_mean')
# ('texture_mean', 'radius_se')
# ('texture_mean', 'texture_se')
# ('texture_mean', 'perimeter_se')
# ('texture_mean', 'area_se')
# ('texture_mean', 'smoothness_se')
# ('texture_mean', 'compactness_se')
# ('texture_mean', 'concavity_se')
# ('texture_mean', 'concave_points_se')
# ('texture_mean', 'symmetry_se')
# ('texture_mean', 'fractal_dimension_se')
# ('texture_mean', 'radius_worst')
# ('texture_mean', 'texture_worst')
# ('texture_mean', 'perimeter_worst')
# ('texture_mean', 'area_worst')
# ('texture_mean', 'smoothness_worst')
# ('texture_mean', 'compactness_worst')
# ('texture_mean', 'concavity_worst')
# ('texture_mean', 'concave_points_worst')
# ('texture_mean', 'symmetry_worst')
# ('texture_mean', 'fractal_dimension_worst')
# ('perimeter_mean', 'area_mean')
# ('perimeter_mean', 'smoothness_mean')
# ('perimeter_mean', 'compactness_mean')
# ('perimeter_mean', 'concavity_mean')
# ('perimeter_mean', 'concave_points_mean')
# ('perimeter_mean', 'symmetry_mean')
# ('perimeter_mean', 'fractal_dimension_mean')
# ('perimeter_mean', 'radius_se')
# ('perimeter_mean', 'texture_se')
# ('perimeter_mean', 'perimeter_se')
# ('perimeter_mean', 'area_se')
# ('perimeter_mean', 'smoothness_se')
# ('perimeter_mean', 'compactness_se')
# ('perimeter_mean', 'concavity_se')
# ('perimeter_mean', 'concave_points_se')
# ('perimeter_mean', 'symmetry_se')
# ('perimeter_mean', 'fractal_dimension_se')
# ('perimeter_mean', 'radius_worst')
# ('perimeter_mean', 'texture_worst')
# ('perimeter_mean', 'perimeter_worst')
# ('perimeter_mean', 'area_worst')
# ('perimeter_mean', 'smoothness_worst')
# ('perimeter_mean', 'compactness_worst')
# ('perimeter_mean', 'concavity_worst')
# ('perimeter_mean', 'concave_points_worst')
# ('perimeter_mean', 'symmetry_worst')
# ('perimeter_mean', 'fractal_dimension_worst')
# ('area_mean', 'smoothness_mean')
# ('area_mean', 'compactness_mean')
# ('area_mean', 'concavity_mean')
# ('area_mean', 'concave_points_mean')
# ('area_mean', 'symmetry_mean')
# ('area_mean', 'fractal_dimension_mean')
# ('area_mean', 'radius_se')
# ('area_mean', 'texture_se')
# ('area_mean', 'perimeter_se')
# ('area_mean', 'area_se')
# ('area_mean', 'smoothness_se')
# ('area_mean', 'compactness_se')
# ('area_mean', 'concavity_se')
# ('area_mean', 'concave_points_se')
# ('area_mean', 'symmetry_se')
# ('area_mean', 'fractal_dimension_se')
# ('area_mean', 'radius_worst')
# ('area_mean', 'texture_worst')
# ('area_mean', 'perimeter_worst')
# ('area_mean', 'area_worst')
# ('area_mean', 'smoothness_worst')
# ('area_mean', 'compactness_worst')
# ('area_mean', 'concavity_worst')
# ('area_mean', 'concave_points_worst')
# ('area_mean', 'symmetry_worst')
# ('area_mean', 'fractal_dimension_worst')
# ('smoothness_mean', 'compactness_mean')
# ('smoothness_mean', 'concavity_mean')
# ('smoothness_mean', 'concave_points_mean')
# ('smoothness_mean', 'symmetry_mean')
# ('smoothness_mean', 'fractal_dimension_mean')
# ('smoothness_mean', 'radius_se')
# ('smoothness_mean', 'texture_se')
# ('smoothness_mean', 'perimeter_se')
# ('smoothness_mean', 'area_se')
# ('smoothness_mean', 'smoothness_se')
# ('smoothness_mean', 'compactness_se')
# ('smoothness_mean', 'concavity_se')
# ('smoothness_mean', 'concave_points_se')
# ('smoothness_mean', 'symmetry_se')
# ('smoothness_mean', 'fractal_dimension_se')
# ('smoothness_mean', 'radius_worst')
# ('smoothness_mean', 'texture_worst')
# ('smoothness_mean', 'perimeter_worst')
# ('smoothness_mean', 'area_worst')
# ('smoothness_mean', 'smoothness_worst')
# ('smoothness_mean', 'compactness_worst')
# ('smoothness_mean', 'concavity_worst')
# ('smoothness_mean', 'concave_points_worst')
# ('smoothness_mean', 'symmetry_worst')
# ('smoothness_mean', 'fractal_dimension_worst')
# ('compactness_mean', 'concavity_mean')
# ('compactness_mean', 'concave_points_mean')
# ('compactness_mean', 'symmetry_mean')
# ('compactness_mean', 'fractal_dimension_mean')
# ('compactness_mean', 'radius_se')
# ('compactness_mean', 'texture_se')
# ('compactness_mean', 'perimeter_se')
# ('compactness_mean', 'area_se')
# ('compactness_mean', 'smoothness_se')
# ('compactness_mean', 'compactness_se')
# ('compactness_mean', 'concavity_se')
# ('compactness_mean', 'concave_points_se')
# ('compactness_mean', 'symmetry_se')
# ('compactness_mean', 'fractal_dimension_se')
# ('compactness_mean', 'radius_worst')
# ('compactness_mean', 'texture_worst')
# ('compactness_mean', 'perimeter_worst')
# ('compactness_mean', 'area_worst')
# ('compactness_mean', 'smoothness_worst')
# ('compactness_mean', 'compactness_worst')
# ('compactness_mean', 'concavity_worst')
# ('compactness_mean', 'concave_points_worst')
# ('compactness_mean', 'symmetry_worst')
# ('compactness_mean', 'fractal_dimension_worst')
# ('concavity_mean', 'concave_points_mean')
# ('concavity_mean', 'symmetry_mean')
# ('concavity_mean', 'fractal_dimension_mean')
# ('concavity_mean', 'radius_se')
# ('concavity_mean', 'texture_se')
# ('concavity_mean', 'perimeter_se')
# ('concavity_mean', 'area_se')
# ('concavity_mean', 'smoothness_se')
# ('concavity_mean', 'compactness_se')
# ('concavity_mean', 'concavity_se')
# ('concavity_mean', 'concave_points_se')
# ('concavity_mean', 'symmetry_se')
# ('concavity_mean', 'fractal_dimension_se')
# ('concavity_mean', 'radius_worst')
# ('concavity_mean', 'texture_worst')
# ('concavity_mean', 'perimeter_worst')
# ('concavity_mean', 'area_worst')
# ('concavity_mean', 'smoothness_worst')
# ('concavity_mean', 'compactness_worst')
# ('concavity_mean', 'concavity_worst')
# ('concavity_mean', 'concave_points_worst')
# ('concavity_mean', 'symmetry_worst')
# ('concavity_mean', 'fractal_dimension_worst')
# ('concave_points_mean', 'symmetry_mean')
# ('concave_points_mean', 'fractal_dimension_mean')
# ('concave_points_mean', 'radius_se')
# ('concave_points_mean', 'texture_se')
# ('concave_points_mean', 'perimeter_se')
# ('concave_points_mean', 'area_se')
# ('concave_points_mean', 'smoothness_se')
# ('concave_points_mean', 'compactness_se')
# ('concave_points_mean', 'concavity_se')
# ('concave_points_mean', 'concave_points_se')
# ('concave_points_mean', 'symmetry_se')
# ('concave_points_mean', 'fractal_dimension_se')
# ('concave_points_mean', 'radius_worst')
# ('concave_points_mean', 'texture_worst')
# ('concave_points_mean', 'perimeter_worst')
# ('concave_points_mean', 'area_worst')
# ('concave_points_mean', 'smoothness_worst')
# ('concave_points_mean', 'compactness_worst')
# ('concave_points_mean', 'concavity_worst')
# ('concave_points_mean', 'concave_points_worst')
# ('concave_points_mean', 'symmetry_worst')
# ('concave_points_mean', 'fractal_dimension_worst')
# ('symmetry_mean', 'fractal_dimension_mean')
# ('symmetry_mean', 'radius_se')
# ('symmetry_mean', 'texture_se')
# ('symmetry_mean', 'perimeter_se')
# ('symmetry_mean', 'area_se')
# ('symmetry_mean', 'smoothness_se')
# ('symmetry_mean', 'compactness_se')
# ('symmetry_mean', 'concavity_se')
# ('symmetry_mean', 'concave_points_se')
# ('symmetry_mean', 'symmetry_se')
# ('symmetry_mean', 'fractal_dimension_se')
# ('symmetry_mean', 'radius_worst')
# ('symmetry_mean', 'texture_worst')
# ('symmetry_mean', 'perimeter_worst')
# ('symmetry_mean', 'area_worst')
# ('symmetry_mean', 'smoothness_worst')
# ('symmetry_mean', 'compactness_worst')
# ('symmetry_mean', 'concavity_worst')
# ('symmetry_mean', 'concave_points_worst')
# ('symmetry_mean', 'symmetry_worst')
# ('symmetry_mean', 'fractal_dimension_worst')
# ('fractal_dimension_mean', 'radius_se')
# ('fractal_dimension_mean', 'texture_se')
# ('fractal_dimension_mean', 'perimeter_se')
# ('fractal_dimension_mean', 'area_se')
# ('fractal_dimension_mean', 'smoothness_se')
# ('fractal_dimension_mean', 'compactness_se')
# ('fractal_dimension_mean', 'concavity_se')
# ('fractal_dimension_mean', 'concave_points_se')
# ('fractal_dimension_mean', 'symmetry_se')
# ('fractal_dimension_mean', 'fractal_dimension_se')
# ('fractal_dimension_mean', 'radius_worst')
# ('fractal_dimension_mean', 'texture_worst')
# ('fractal_dimension_mean', 'perimeter_worst')
# ('fractal_dimension_mean', 'area_worst')
# ('fractal_dimension_mean', 'smoothness_worst')
# ('fractal_dimension_mean', 'compactness_worst')
# ('fractal_dimension_mean', 'concavity_worst')
# ('fractal_dimension_mean', 'concave_points_worst')
# ('fractal_dimension_mean', 'symmetry_worst')
# ('fractal_dimension_mean', 'fractal_dimension_worst')
# ('radius_se', 'texture_se')
# ('radius_se', 'perimeter_se')
# ('radius_se', 'area_se')
# ('radius_se', 'smoothness_se')
# ('radius_se', 'compactness_se')
# ('radius_se', 'concavity_se')
# ('radius_se', 'concave_points_se')
# ('radius_se', 'symmetry_se')
# ('radius_se', 'fractal_dimension_se')
# ('radius_se', 'radius_worst')
# ('radius_se', 'texture_worst')
# ('radius_se', 'perimeter_worst')
# ('radius_se', 'area_worst')
# ('radius_se', 'smoothness_worst')
# ('radius_se', 'compactness_worst')
# ('radius_se', 'concavity_worst')
# ('radius_se', 'concave_points_worst')
# ('radius_se', 'symmetry_worst')
# ('radius_se', 'fractal_dimension_worst')
# ('texture_se', 'perimeter_se')
# ('texture_se', 'area_se')
# ('texture_se', 'smoothness_se')
# ('texture_se', 'compactness_se')
# ('texture_se', 'concavity_se')
# ('texture_se', 'concave_points_se')
# ('texture_se', 'symmetry_se')
# ('texture_se', 'fractal_dimension_se')
# ('texture_se', 'radius_worst')
# ('texture_se', 'texture_worst')
# ('texture_se', 'perimeter_worst')
# ('texture_se', 'area_worst')
# ('texture_se', 'smoothness_worst')
# ('texture_se', 'compactness_worst')
# ('texture_se', 'concavity_worst')
# ('texture_se', 'concave_points_worst')
# ('texture_se', 'symmetry_worst')
# ('texture_se', 'fractal_dimension_worst')
# ('perimeter_se', 'area_se')
# ('perimeter_se', 'smoothness_se')
# ('perimeter_se', 'compactness_se')
# ('perimeter_se', 'concavity_se')
# ('perimeter_se', 'concave_points_se')
# ('perimeter_se', 'symmetry_se')
# ('perimeter_se', 'fractal_dimension_se')
# ('perimeter_se', 'radius_worst')
# ('perimeter_se', 'texture_worst')
# ('perimeter_se', 'perimeter_worst')
# ('perimeter_se', 'area_worst')
# ('perimeter_se', 'smoothness_worst')
# ('perimeter_se', 'compactness_worst')
# ('perimeter_se', 'concavity_worst')
# ('perimeter_se', 'concave_points_worst')
# ('perimeter_se', 'symmetry_worst')
# ('perimeter_se', 'fractal_dimension_worst')
# ('area_se', 'smoothness_se')
# ('area_se', 'compactness_se')
# ('area_se', 'concavity_se')
# ('area_se', 'concave_points_se')
# ('area_se', 'symmetry_se')
# ('area_se', 'fractal_dimension_se')
# ('area_se', 'radius_worst')
# ('area_se', 'texture_worst')
# ('area_se', 'perimeter_worst')
# ('area_se', 'area_worst')
# ('area_se', 'smoothness_worst')
# ('area_se', 'compactness_worst')
# ('area_se', 'concavity_worst')
# ('area_se', 'concave_points_worst')
# ('area_se', 'symmetry_worst')
# ('area_se', 'fractal_dimension_worst')
# ('smoothness_se', 'compactness_se')
# ('smoothness_se', 'concavity_se')
# ('smoothness_se', 'concave_points_se')
# ('smoothness_se', 'symmetry_se')
# ('smoothness_se', 'fractal_dimension_se')
# ('smoothness_se', 'radius_worst')
# ('smoothness_se', 'texture_worst')
# ('smoothness_se', 'perimeter_worst')
# ('smoothness_se', 'area_worst')
# ('smoothness_se', 'smoothness_worst')
# ('smoothness_se', 'compactness_worst')
# ('smoothness_se', 'concavity_worst')
# ('smoothness_se', 'concave_points_worst')
# ('smoothness_se', 'symmetry_worst')
# ('smoothness_se', 'fractal_dimension_worst')
# ('compactness_se', 'concavity_se')
# ('compactness_se', 'concave_points_se')
# ('compactness_se', 'symmetry_se')
# ('compactness_se', 'fractal_dimension_se')
# ('compactness_se', 'radius_worst')
# ('compactness_se', 'texture_worst')
# ('compactness_se', 'perimeter_worst')
# ('compactness_se', 'area_worst')
# ('compactness_se', 'smoothness_worst')
# ('compactness_se', 'compactness_worst')
# ('compactness_se', 'concavity_worst')
# ('compactness_se', 'concave_points_worst')
# ('compactness_se', 'symmetry_worst')
# ('compactness_se', 'fractal_dimension_worst')
# ('concavity_se', 'concave_points_se')
# ('concavity_se', 'symmetry_se')
# ('concavity_se', 'fractal_dimension_se')
# ('concavity_se', 'radius_worst')
# ('concavity_se', 'texture_worst')
# ('concavity_se', 'perimeter_worst')
# ('concavity_se', 'area_worst')
# ('concavity_se', 'smoothness_worst')
# ('concavity_se', 'compactness_worst')
# ('concavity_se', 'concavity_worst')
# ('concavity_se', 'concave_points_worst')
# ('concavity_se', 'symmetry_worst')
# ('concavity_se', 'fractal_dimension_worst')
# ('concave_points_se', 'symmetry_se')
# ('concave_points_se', 'fractal_dimension_se')
# ('concave_points_se', 'radius_worst')
# ('concave_points_se', 'texture_worst')
# ('concave_points_se', 'perimeter_worst')
# ('concave_points_se', 'area_worst')
# ('concave_points_se', 'smoothness_worst')
# ('concave_points_se', 'compactness_worst')
# ('concave_points_se', 'concavity_worst')
# ('concave_points_se', 'concave_points_worst')
# ('concave_points_se', 'symmetry_worst')
# ('concave_points_se', 'fractal_dimension_worst')
# ('symmetry_se', 'fractal_dimension_se')
# ('symmetry_se', 'radius_worst')
# ('symmetry_se', 'texture_worst')
# ('symmetry_se', 'perimeter_worst')
# ('symmetry_se', 'area_worst')
# ('symmetry_se', 'smoothness_worst')
# ('symmetry_se', 'compactness_worst')
# ('symmetry_se', 'concavity_worst')
# ('symmetry_se', 'concave_points_worst')
# ('symmetry_se', 'symmetry_worst')
# ('symmetry_se', 'fractal_dimension_worst')
# ('fractal_dimension_se', 'radius_worst')
# ('fractal_dimension_se', 'texture_worst')
# ('fractal_dimension_se', 'perimeter_worst')
# ('fractal_dimension_se', 'area_worst')
# ('fractal_dimension_se', 'smoothness_worst')
# ('fractal_dimension_se', 'compactness_worst')
# ('fractal_dimension_se', 'concavity_worst')
# ('fractal_dimension_se', 'concave_points_worst')
# ('fractal_dimension_se', 'symmetry_worst')
# ('fractal_dimension_se', 'fractal_dimension_worst')
# ('radius_worst', 'texture_worst')
# ('radius_worst', 'perimeter_worst')
# ('radius_worst', 'area_worst')
# ('radius_worst', 'smoothness_worst')
# ('radius_worst', 'compactness_worst')
# ('radius_worst', 'concavity_worst')
# ('radius_worst', 'concave_points_worst')
# ('radius_worst', 'symmetry_worst')
# ('radius_worst', 'fractal_dimension_worst')
# ('texture_worst', 'perimeter_worst')
# ('texture_worst', 'area_worst')
# ('texture_worst', 'smoothness_worst')
# ('texture_worst', 'compactness_worst')
# ('texture_worst', 'concavity_worst')
# ('texture_worst', 'concave_points_worst')
# ('texture_worst', 'symmetry_worst')
# ('texture_worst', 'fractal_dimension_worst')
# ('perimeter_worst', 'area_worst')
# ('perimeter_worst', 'smoothness_worst')
# ('perimeter_worst', 'compactness_worst')
# ('perimeter_worst', 'concavity_worst')
# ('perimeter_worst', 'concave_points_worst')
# ('perimeter_worst', 'symmetry_worst')
# ('perimeter_worst', 'fractal_dimension_worst')
# ('area_worst', 'smoothness_worst')
# ('area_worst', 'compactness_worst')
# ('area_worst', 'concavity_worst')
# ('area_worst', 'concave_points_worst')
# ('area_worst', 'symmetry_worst')
# ('area_worst', 'fractal_dimension_worst')
# ('smoothness_worst', 'compactness_worst')
# ('smoothness_worst', 'concavity_worst')
# ('smoothness_worst', 'concave_points_worst')
# ('smoothness_worst', 'symmetry_worst')
# ('smoothness_worst', 'fractal_dimension_worst')
# ('compactness_worst', 'concavity_worst')
# ('compactness_worst', 'concave_points_worst')
# ('compactness_worst', 'symmetry_worst')
# ('compactness_worst', 'fractal_dimension_worst')
# ('concavity_worst', 'concave_points_worst')
# ('concavity_worst', 'symmetry_worst')
# ('concavity_worst', 'fractal_dimension_worst')
# ('concave_points_worst', 'symmetry_worst')
# ('concave_points_worst', 'fractal_dimension_worst')
# ('symmetry_worst', 'fractal_dimension_worst')
# ('radius_mean', 'texture_mean', 'perimeter_mean')
# ('radius_mean', 'texture_mean', 'area_mean')
# ('radius_mean', 'texture_mean', 'smoothness_mean')
# ('radius_mean', 'texture_mean', 'compactness_mean')
# ('radius_mean', 'texture_mean', 'concavity_mean')
# ('radius_mean', 'texture_mean', 'concave_points_mean')
# ('radius_mean', 'texture_mean', 'symmetry_mean')
# ('radius_mean', 'texture_mean', 'fractal_dimension_mean')
# ('radius_mean', 'texture_mean', 'radius_se')
# ('radius_mean', 'texture_mean', 'texture_se')
# ('radius_mean', 'texture_mean', 'perimeter_se')
# ('radius_mean', 'texture_mean', 'area_se')
# ('radius_mean', 'texture_mean', 'smoothness_se')
# ('radius_mean', 'texture_mean', 'compactness_se')
# ('radius_mean', 'texture_mean', 'concavity_se')
# ('radius_mean', 'texture_mean', 'concave_points_se')
# ('radius_mean', 'texture_mean', 'symmetry_se')
# ('radius_mean', 'texture_mean', 'fractal_dimension_se')
# ('radius_mean', 'texture_mean', 'radius_worst')
# ('radius_mean', 'texture_mean', 'texture_worst')
# ('radius_mean', 'texture_mean', 'perimeter_worst')
# ('radius_mean', 'texture_mean', 'area_worst')
# ('radius_mean', 'texture_mean', 'smoothness_worst')
# ('radius_mean', 'texture_mean', 'compactness_worst')
# ('radius_mean', 'texture_mean', 'concavity_worst')
# ('radius_mean', 'texture_mean', 'concave_points_worst')
# ('radius_mean', 'texture_mean', 'symmetry_worst')
# ('radius_mean', 'texture_mean', 'fractal_dimension_worst')
# ('radius_mean', 'perimeter_mean', 'area_mean')
# ('radius_mean', 'perimeter_mean', 'smoothness_mean')
# ('radius_mean', 'perimeter_mean', 'compactness_mean')
# ('radius_mean', 'perimeter_mean', 'concavity_mean')
# ('radius_mean', 'perimeter_mean', 'concave_points_mean')
# ('radius_mean', 'perimeter_mean', 'symmetry_mean')
# ('radius_mean', 'perimeter_mean', 'fractal_dimension_mean')
# ('radius_mean', 'perimeter_mean', 'radius_se')
# ('radius_mean', 'perimeter_mean', 'texture_se')
# ('radius_mean', 'perimeter_mean', 'perimeter_se')
# ('radius_mean', 'perimeter_mean', 'area_se')
# ('radius_mean', 'perimeter_mean', 'smoothness_se')
# ('radius_mean', 'perimeter_mean', 'compactness_se')
# ('radius_mean', 'perimeter_mean', 'concavity_se')
# ('radius_mean', 'perimeter_mean', 'concave_points_se')
# ('radius_mean', 'perimeter_mean', 'symmetry_se')
# ('radius_mean', 'perimeter_mean', 'fractal_dimension_se')
# ('radius_mean', 'perimeter_mean', 'radius_worst')
# ('radius_mean', 'perimeter_mean', 'texture_worst')
# ('radius_mean', 'perimeter_mean', 'perimeter_worst')
# ('radius_mean', 'perimeter_mean', 'area_worst')
# ('radius_mean', 'perimeter_mean', 'smoothness_worst')
# ('radius_mean', 'perimeter_mean', 'compactness_worst')
# ('radius_mean', 'perimeter_mean', 'concavity_worst')
# ('radius_mean', 'perimeter_mean', 'concave_points_worst')
# ('radius_mean', 'perimeter_mean', 'symmetry_worst')
# ('radius_mean', 'perimeter_mean', 'fractal_dimension_worst')
# ('radius_mean', 'area_mean', 'smoothness_mean')
# ('radius_mean', 'area_mean', 'compactness_mean')
# ('radius_mean', 'area_mean', 'concavity_mean')
# ('radius_mean', 'area_mean', 'concave_points_mean')
# ('radius_mean', 'area_mean', 'symmetry_mean')
# ('radius_mean', 'area_mean', 'fractal_dimension_mean')
# ('radius_mean', 'area_mean', 'radius_se')
# ('radius_mean', 'area_mean', 'texture_se')
# ('radius_mean', 'area_mean', 'perimeter_se')
# ('radius_mean', 'area_mean', 'area_se')
# ('radius_mean', 'area_mean', 'smoothness_se')
# ('radius_mean', 'area_mean', 'compactness_se')
# ('radius_mean', 'area_mean', 'concavity_se')
# ('radius_mean', 'area_mean', 'concave_points_se')
# ('radius_mean', 'area_mean', 'symmetry_se')
# ('radius_mean', 'area_mean', 'fractal_dimension_se')
# ('radius_mean', 'area_mean', 'radius_worst')
# ('radius_mean', 'area_mean', 'texture_worst')
# ('radius_mean', 'area_mean', 'perimeter_worst')
# ('radius_mean', 'area_mean', 'area_worst')
# ('radius_mean', 'area_mean', 'smoothness_worst')
# ('radius_mean', 'area_mean', 'compactness_worst')
# ('radius_mean', 'area_mean', 'concavity_worst')
# ('radius_mean', 'area_mean', 'concave_points_worst')
# ('radius_mean', 'area_mean', 'symmetry_worst')
# ('radius_mean', 'area_mean', 'fractal_dimension_worst')
# ('radius_mean', 'smoothness_mean', 'compactness_mean')
# ('radius_mean', 'smoothness_mean', 'concavity_mean')
# ('radius_mean', 'smoothness_mean', 'concave_points_mean')
# ('radius_mean', 'smoothness_mean', 'symmetry_mean')
# ('radius_mean', 'smoothness_mean', 'fractal_dimension_mean')
# ('radius_mean', 'smoothness_mean', 'radius_se')
# ('radius_mean', 'smoothness_mean', 'texture_se')
# ('radius_mean', 'smoothness_mean', 'perimeter_se')
# ('radius_mean', 'smoothness_mean', 'area_se')
# ('radius_mean', 'smoothness_mean', 'smoothness_se')
# ('radius_mean', 'smoothness_mean', 'compactness_se')
# ('radius_mean', 'smoothness_mean', 'concavity_se')
# ('radius_mean', 'smoothness_mean', 'concave_points_se')
# ('radius_mean', 'smoothness_mean', 'symmetry_se')
# ('radius_mean', 'smoothness_mean', 'fractal_dimension_se')
# ('radius_mean', 'smoothness_mean', 'radius_worst')
# ('radius_mean', 'smoothness_mean', 'texture_worst')
# ('radius_mean', 'smoothness_mean', 'perimeter_worst')
# ('radius_mean', 'smoothness_mean', 'area_worst')
# ('radius_mean', 'smoothness_mean', 'smoothness_worst')
# ('radius_mean', 'smoothness_mean', 'compactness_worst')
# ('radius_mean', 'smoothness_mean', 'concavity_worst')
# ('radius_mean', 'smoothness_mean', 'concave_points_worst')
# ('radius_mean', 'smoothness_mean', 'symmetry_worst')
# ('radius_mean', 'smoothness_mean', 'fractal_dimension_worst')
# ('radius_mean', 'compactness_mean', 'concavity_mean')
# ('radius_mean', 'compactness_mean', 'concave_points_mean')
# ('radius_mean', 'compactness_mean', 'symmetry_mean')
# ('radius_mean', 'compactness_mean', 'fractal_dimension_mean')
# ('radius_mean', 'compactness_mean', 'radius_se')
# ('radius_mean', 'compactness_mean', 'texture_se')
# ('radius_mean', 'compactness_mean', 'perimeter_se')
# ('radius_mean', 'compactness_mean', 'area_se')
# ('radius_mean', 'compactness_mean', 'smoothness_se')
# ('radius_mean', 'compactness_mean', 'compactness_se')
# ('radius_mean', 'compactness_mean', 'concavity_se')
# ('radius_mean', 'compactness_mean', 'concave_points_se')
# ('radius_mean', 'compactness_mean', 'symmetry_se')
# ('radius_mean', 'compactness_mean', 'fractal_dimension_se')
# ('radius_mean', 'compactness_mean', 'radius_worst')
# ('radius_mean', 'compactness_mean', 'texture_worst')
# ('radius_mean', 'compactness_mean', 'perimeter_worst')
# ('radius_mean', 'compactness_mean', 'area_worst')
# ('radius_mean', 'compactness_mean', 'smoothness_worst')
# ('radius_mean', 'compactness_mean', 'compactness_worst')
# ('radius_mean', 'compactness_mean', 'concavity_worst')
# ('radius_mean', 'compactness_mean', 'concave_points_worst')
# ('radius_mean', 'compactness_mean', 'symmetry_worst')
# ('radius_mean', 'compactness_mean', 'fractal_dimension_worst')
# ('radius_mean', 'concavity_mean', 'concave_points_mean')
# ('radius_mean', 'concavity_mean', 'symmetry_mean')
# ('radius_mean', 'concavity_mean', 'fractal_dimension_mean')
# ('radius_mean', 'concavity_mean', 'radius_se')
# ('radius_mean', 'concavity_mean', 'texture_se')
# ('radius_mean', 'concavity_mean', 'perimeter_se')
# ('radius_mean', 'concavity_mean', 'area_se')
# ('radius_mean', 'concavity_mean', 'smoothness_se')
# ('radius_mean', 'concavity_mean', 'compactness_se')
# ('radius_mean', 'concavity_mean', 'concavity_se')
# ('radius_mean', 'concavity_mean', 'concave_points_se')
# ('radius_mean', 'concavity_mean', 'symmetry_se')
# ('radius_mean', 'concavity_mean', 'fractal_dimension_se')
# ('radius_mean', 'concavity_mean', 'radius_worst')
# ('radius_mean', 'concavity_mean', 'texture_worst')
# ('radius_mean', 'concavity_mean', 'perimeter_worst')
# ('radius_mean', 'concavity_mean', 'area_worst')
# ('radius_mean', 'concavity_mean', 'smoothness_worst')
# ('radius_mean', 'concavity_mean', 'compactness_worst')
# ('radius_mean', 'concavity_mean', 'concavity_worst')
# ('radius_mean', 'concavity_mean', 'concave_points_worst')
# ('radius_mean', 'concavity_mean', 'symmetry_worst')
# ('radius_mean', 'concavity_mean', 'fractal_dimension_worst')
# ('radius_mean', 'concave_points_mean', 'symmetry_mean')
# ('radius_mean', 'concave_points_mean', 'fractal_dimension_mean')
# ('radius_mean', 'concave_points_mean', 'radius_se')
# ('radius_mean', 'concave_points_mean', 'texture_se')
# ('radius_mean', 'concave_points_mean', 'perimeter_se')
# ('radius_mean', 'concave_points_mean', 'area_se')
# ('radius_mean', 'concave_points_mean', 'smoothness_se')
# ('radius_mean', 'concave_points_mean', 'compactness_se')
# ('radius_mean', 'concave_points_mean', 'concavity_se')
# ('radius_mean', 'concave_points_mean', 'concave_points_se')
# ('radius_mean', 'concave_points_mean', 'symmetry_se')
# ('radius_mean', 'concave_points_mean', 'fractal_dimension_se')
# ('radius_mean', 'concave_points_mean', 'radius_worst')
# ('radius_mean', 'concave_points_mean', 'texture_worst')
# ('radius_mean', 'concave_points_mean', 'perimeter_worst')
# ('radius_mean', 'concave_points_mean', 'area_worst')
# ('radius_mean', 'concave_points_mean', 'smoothness_worst')
# ('radius_mean', 'concave_points_mean', 'compactness_worst')
# ('radius_mean', 'concave_points_mean', 'concavity_worst')
# ('radius_mean', 'concave_points_mean', 'concave_points_worst')
# ('radius_mean', 'concave_points_mean', 'symmetry_worst')
# ('radius_mean', 'concave_points_mean', 'fractal_dimension_worst')
# ('radius_mean', 'symmetry_mean', 'fractal_dimension_mean')
# ('radius_mean', 'symmetry_mean', 'radius_se')
# ('radius_mean', 'symmetry_mean', 'texture_se')
# ('radius_mean', 'symmetry_mean', 'perimeter_se')
# ('radius_mean', 'symmetry_mean', 'area_se')
# ('radius_mean', 'symmetry_mean', 'smoothness_se')
# ('radius_mean', 'symmetry_mean', 'compactness_se')
# ('radius_mean', 'symmetry_mean', 'concavity_se')
# ('radius_mean', 'symmetry_mean', 'concave_points_se')
# ('radius_mean', 'symmetry_mean', 'symmetry_se')
# ('radius_mean', 'symmetry_mean', 'fractal_dimension_se')
# ('radius_mean', 'symmetry_mean', 'radius_worst')
# ('radius_mean', 'symmetry_mean', 'texture_worst')
# ('radius_mean', 'symmetry_mean', 'perimeter_worst')
# ('radius_mean', 'symmetry_mean', 'area_worst')
# ('radius_mean', 'symmetry_mean', 'smoothness_worst')
# ('radius_mean', 'symmetry_mean', 'compactness_worst')
# ('radius_mean', 'symmetry_mean', 'concavity_worst')
# ('radius_mean', 'symmetry_mean', 'concave_points_worst')
# ('radius_mean', 'symmetry_mean', 'symmetry_worst')
# ('radius_mean', 'symmetry_mean', 'fractal_dimension_worst')
# ('radius_mean', 'fractal_dimension_mean', 'radius_se')
# ('radius_mean', 'fractal_dimension_mean', 'texture_se')
# ('radius_mean', 'fractal_dimension_mean', 'perimeter_se')
# ('radius_mean', 'fractal_dimension_mean', 'area_se')
# ('radius_mean', 'fractal_dimension_mean', 'smoothness_se')
# ('radius_mean', 'fractal_dimension_mean', 'compactness_se')
# ('radius_mean', 'fractal_dimension_mean', 'concavity_se')
# ('radius_mean', 'fractal_dimension_mean', 'concave_points_se')
# ('radius_mean', 'fractal_dimension_mean', 'symmetry_se')
# ('radius_mean', 'fractal_dimension_mean', 'fractal_dimension_se')
# ('radius_mean', 'fractal_dimension_mean', 'radius_worst')
# ('radius_mean', 'fractal_dimension_mean', 'texture_worst')
# ('radius_mean', 'fractal_dimension_mean', 'perimeter_worst')
# ('radius_mean', 'fractal_dimension_mean', 'area_worst')
# ('radius_mean', 'fractal_dimension_mean', 'smoothness_worst')
# ('radius_mean', 'fractal_dimension_mean', 'compactness_worst')
# ('radius_mean', 'fractal_dimension_mean', 'concavity_worst')
# ('radius_mean', 'fractal_dimension_mean', 'concave_points_worst')
# ('radius_mean', 'fractal_dimension_mean', 'symmetry_worst')
# ('radius_mean', 'fractal_dimension_mean', 'fractal_dimension_worst')
# ('radius_mean', 'radius_se', 'texture_se')
# ('radius_mean', 'radius_se', 'perimeter_se')
# ('radius_mean', 'radius_se', 'area_se')
# ('radius_mean', 'radius_se', 'smoothness_se')
# ('radius_mean', 'radius_se', 'compactness_se')
# ('radius_mean', 'radius_se', 'concavity_se')
# ('radius_mean', 'radius_se', 'concave_points_se')
# ('radius_mean', 'radius_se', 'symmetry_se')
# ('radius_mean', 'radius_se', 'fractal_dimension_se')
# ('radius_mean', 'radius_se', 'radius_worst')
# ('radius_mean', 'radius_se', 'texture_worst')
# ('radius_mean', 'radius_se', 'perimeter_worst')
# ('radius_mean', 'radius_se', 'area_worst')
# ('radius_mean', 'radius_se', 'smoothness_worst')
# ('radius_mean', 'radius_se', 'compactness_worst')
# ('radius_mean', 'radius_se', 'concavity_worst')
# ('radius_mean', 'radius_se', 'concave_points_worst')
# ('radius_mean', 'radius_se', 'symmetry_worst')
# ('radius_mean', 'radius_se', 'fractal_dimension_worst')
# ('radius_mean', 'texture_se', 'perimeter_se')
# ('radius_mean', 'texture_se', 'area_se')
# ('radius_mean', 'texture_se', 'smoothness_se')
# ('radius_mean', 'texture_se', 'compactness_se')
# ('radius_mean', 'texture_se', 'concavity_se')
# ('radius_mean', 'texture_se', 'concave_points_se')
# ('radius_mean', 'texture_se', 'symmetry_se')
# ('radius_mean', 'texture_se', 'fractal_dimension_se')
# ('radius_mean', 'texture_se', 'radius_worst')
# ('radius_mean', 'texture_se', 'texture_worst')
# ('radius_mean', 'texture_se', 'perimeter_worst')
# ('radius_mean', 'texture_se', 'area_worst')
# ('radius_mean', 'texture_se', 'smoothness_worst')
# ('radius_mean', 'texture_se', 'compactness_worst')
# ('radius_mean', 'texture_se', 'concavity_worst')
# ('radius_mean', 'texture_se', 'concave_points_worst')
# ('radius_mean', 'texture_se', 'symmetry_worst')
# ('radius_mean', 'texture_se', 'fractal_dimension_worst')
# ('radius_mean', 'perimeter_se', 'area_se')
# ('radius_mean', 'perimeter_se', 'smoothness_se')
# ('radius_mean', 'perimeter_se', 'compactness_se')
# ('radius_mean', 'perimeter_se', 'concavity_se')
# ('radius_mean', 'perimeter_se', 'concave_points_se')
# ('radius_mean', 'perimeter_se', 'symmetry_se')
# ('radius_mean', 'perimeter_se', 'fractal_dimension_se')
# ('radius_mean', 'perimeter_se', 'radius_worst')
# ('radius_mean', 'perimeter_se', 'texture_worst')
# ('radius_mean', 'perimeter_se', 'perimeter_worst')
# ('radius_mean', 'perimeter_se', 'area_worst')
# ('radius_mean', 'perimeter_se', 'smoothness_worst')
# ('radius_mean', 'perimeter_se', 'compactness_worst')
# ('radius_mean', 'perimeter_se', 'concavity_worst')
# ('radius_mean', 'perimeter_se', 'concave_points_worst')
# ('radius_mean', 'perimeter_se', 'symmetry_worst')
# ('radius_mean', 'perimeter_se', 'fractal_dimension_worst')
# ('radius_mean', 'area_se', 'smoothness_se')
# ('radius_mean', 'area_se', 'compactness_se')
# ('radius_mean', 'area_se', 'concavity_se')
# ('radius_mean', 'area_se', 'concave_points_se')
# ('radius_mean', 'area_se', 'symmetry_se')
# ('radius_mean', 'area_se', 'fractal_dimension_se')
# ('radius_mean', 'area_se', 'radius_worst')
# ('radius_mean', 'area_se', 'texture_worst')
# ('radius_mean', 'area_se', 'perimeter_worst')
# ('radius_mean', 'area_se', 'area_worst')
# ('radius_mean', 'area_se', 'smoothness_worst')
# ('radius_mean', 'area_se', 'compactness_worst')
# ('radius_mean', 'area_se', 'concavity_worst')
# ('radius_mean', 'area_se', 'concave_points_worst')
# ('radius_mean', 'area_se', 'symmetry_worst')
# ('radius_mean', 'area_se', 'fractal_dimension_worst')
# ('radius_mean', 'smoothness_se', 'compactness_se')
# ('radius_mean', 'smoothness_se', 'concavity_se')
# ('radius_mean', 'smoothness_se', 'concave_points_se')
# ('radius_mean', 'smoothness_se', 'symmetry_se')
# ('radius_mean', 'smoothness_se', 'fractal_dimension_se')
# ('radius_mean', 'smoothness_se', 'radius_worst')
# ('radius_mean', 'smoothness_se', 'texture_worst')
# ('radius_mean', 'smoothness_se', 'perimeter_worst')
# ('radius_mean', 'smoothness_se', 'area_worst')
# ('radius_mean', 'smoothness_se', 'smoothness_worst')
# ('radius_mean', 'smoothness_se', 'compactness_worst')
# ('radius_mean', 'smoothness_se', 'concavity_worst')
# ('radius_mean', 'smoothness_se', 'concave_points_worst')
# ('radius_mean', 'smoothness_se', 'symmetry_worst')
# ('radius_mean', 'smoothness_se', 'fractal_dimension_worst')
# ('radius_mean', 'compactness_se', 'concavity_se')
# ('radius_mean', 'compactness_se', 'concave_points_se')
# ('radius_mean', 'compactness_se', 'symmetry_se')
# ('radius_mean', 'compactness_se', 'fractal_dimension_se')
# ('radius_mean', 'compactness_se', 'radius_worst')
# ('radius_mean', 'compactness_se', 'texture_worst')
# ('radius_mean', 'compactness_se', 'perimeter_worst')
# ('radius_mean', 'compactness_se', 'area_worst')
# ('radius_mean', 'compactness_se', 'smoothness_worst')
# ('radius_mean', 'compactness_se', 'compactness_worst')
# ('radius_mean', 'compactness_se', 'concavity_worst')
# ('radius_mean', 'compactness_se', 'concave_points_worst')
# ('radius_mean', 'compactness_se', 'symmetry_worst')
# ('radius_mean', 'compactness_se', 'fractal_dimension_worst')
# ('radius_mean', 'concavity_se', 'concave_points_se')
# ('radius_mean', 'concavity_se', 'symmetry_se')
# ('radius_mean', 'concavity_se', 'fractal_dimension_se')
# ('radius_mean', 'concavity_se', 'radius_worst')
# ('radius_mean', 'concavity_se', 'texture_worst')
# ('radius_mean', 'concavity_se', 'perimeter_worst')
# ('radius_mean', 'concavity_se', 'area_worst')
# ('radius_mean', 'concavity_se', 'smoothness_worst')
# ('radius_mean', 'concavity_se', 'compactness_worst')
# ('radius_mean', 'concavity_se', 'concavity_worst')
# ('radius_mean', 'concavity_se', 'concave_points_worst')
# ('radius_mean', 'concavity_se', 'symmetry_worst')
# ('radius_mean', 'concavity_se', 'fractal_dimension_worst')
# ('radius_mean', 'concave_points_se', 'symmetry_se')
# ('radius_mean', 'concave_points_se', 'fractal_dimension_se')
# ('radius_mean', 'concave_points_se', 'radius_worst')
# ('radius_mean', 'concave_points_se', 'texture_worst')
# ('radius_mean', 'concave_points_se', 'perimeter_worst')
# ('radius_mean', 'concave_points_se', 'area_worst')
# ('radius_mean', 'concave_points_se', 'smoothness_worst')
# ('radius_mean', 'concave_points_se', 'compactness_worst')
# ('radius_mean', 'concave_points_se', 'concavity_worst')
# ('radius_mean', 'concave_points_se', 'concave_points_worst')
# ('radius_mean', 'concave_points_se', 'symmetry_worst')
# ('radius_mean', 'concave_points_se', 'fractal_dimension_worst')
# ('radius_mean', 'symmetry_se', 'fractal_dimension_se')
# ('radius_mean', 'symmetry_se', 'radius_worst')
# ('radius_mean', 'symmetry_se', 'texture_worst')
# ('radius_mean', 'symmetry_se', 'perimeter_worst')
# ('radius_mean', 'symmetry_se', 'area_worst')
# ('radius_mean', 'symmetry_se', 'smoothness_worst')
# ('radius_mean', 'symmetry_se', 'compactness_worst')
# ('radius_mean', 'symmetry_se', 'concavity_worst')
# ('radius_mean', 'symmetry_se', 'concave_points_worst')
# ('radius_mean', 'symmetry_se', 'symmetry_worst')
# ('radius_mean', 'symmetry_se', 'fractal_dimension_worst')
# ('radius_mean', 'fractal_dimension_se', 'radius_worst')
# ('radius_mean', 'fractal_dimension_se', 'texture_worst')
# ('radius_mean', 'fractal_dimension_se', 'perimeter_worst')
# ('radius_mean', 'fractal_dimension_se', 'area_worst')
# ('radius_mean', 'fractal_dimension_se', 'smoothness_worst')
# ('radius_mean', 'fractal_dimension_se', 'compactness_worst')
# ('radius_mean', 'fractal_dimension_se', 'concavity_worst')
# ('radius_mean', 'fractal_dimension_se', 'concave_points_worst')
# ('radius_mean', 'fractal_dimension_se', 'symmetry_worst')
# ('radius_mean', 'fractal_dimension_se', 'fractal_dimension_worst')
# ('radius_mean', 'radius_worst', 'texture_worst')
# ('radius_mean', 'radius_worst', 'perimeter_worst')
# ('radius_mean', 'radius_worst', 'area_worst')
# ('radius_mean', 'radius_worst', 'smoothness_worst')
# ('radius_mean', 'radius_worst', 'compactness_worst')
# ('radius_mean', 'radius_worst', 'concavity_worst')
# ('radius_mean', 'radius_worst', 'concave_points_worst')
# ('radius_mean', 'radius_worst', 'symmetry_worst')
# ('radius_mean', 'radius_worst', 'fractal_dimension_worst')
# ('radius_mean', 'texture_worst', 'perimeter_worst')
# ('radius_mean', 'texture_worst', 'area_worst')
# ('radius_mean', 'texture_worst', 'smoothness_worst')
# ('radius_mean', 'texture_worst', 'compactness_worst')
# ('radius_mean', 'texture_worst', 'concavity_worst')
# ('radius_mean', 'texture_worst', 'concave_points_worst')
# ('radius_mean', 'texture_worst', 'symmetry_worst')
# ('radius_mean', 'texture_worst', 'fractal_dimension_worst')
# ('radius_mean', 'perimeter_worst', 'area_worst')
# ('radius_mean', 'perimeter_worst', 'smoothness_worst')
# ('radius_mean', 'perimeter_worst', 'compactness_worst')
# ('radius_mean', 'perimeter_worst', 'concavity_worst')
# ('radius_mean', 'perimeter_worst', 'concave_points_worst')
# ('radius_mean', 'perimeter_worst', 'symmetry_worst')
# ('radius_mean', 'perimeter_worst', 'fractal_dimension_worst')
# ('radius_mean', 'area_worst', 'smoothness_worst')
# ('radius_mean', 'area_worst', 'compactness_worst')
# ('radius_mean', 'area_worst', 'concavity_worst')
# ('radius_mean', 'area_worst', 'concave_points_worst')
# ('radius_mean', 'area_worst', 'symmetry_worst')
# ('radius_mean', 'area_worst', 'fractal_dimension_worst')
# ('radius_mean', 'smoothness_worst', 'compactness_worst')
# ('radius_mean', 'smoothness_worst', 'concavity_worst')
# ('radius_mean', 'smoothness_worst', 'concave_points_worst')
# ('radius_mean', 'smoothness_worst', 'symmetry_worst')
# ('radius_mean', 'smoothness_worst', 'fractal_dimension_worst')
# ('radius_mean', 'compactness_worst', 'concavity_worst')
# ('radius_mean', 'compactness_worst', 'concave_points_worst')
# ('radius_mean', 'compactness_worst', 'symmetry_worst')
# ('radius_mean', 'compactness_worst', 'fractal_dimension_worst')
# ('radius_mean', 'concavity_worst', 'concave_points_worst')
# ('radius_mean', 'concavity_worst', 'symmetry_worst')
# ('radius_mean', 'concavity_worst', 'fractal_dimension_worst')
# ('radius_mean', 'concave_points_worst', 'symmetry_worst')
# ('radius_mean', 'concave_points_worst', 'fractal_dimension_worst')
# ('radius_mean', 'symmetry_worst', 'fractal_dimension_worst')
# ('texture_mean', 'perimeter_mean', 'area_mean')
# ('texture_mean', 'perimeter_mean', 'smoothness_mean')
# ('texture_mean', 'perimeter_mean', 'compactness_mean')
# ('texture_mean', 'perimeter_mean', 'concavity_mean')
# ('texture_mean', 'perimeter_mean', 'concave_points_mean')
# ('texture_mean', 'perimeter_mean', 'symmetry_mean')
# ('texture_mean', 'perimeter_mean', 'fractal_dimension_mean')
# ('texture_mean', 'perimeter_mean', 'radius_se')
# ('texture_mean', 'perimeter_mean', 'texture_se')
# ('texture_mean', 'perimeter_mean', 'perimeter_se')
# ('texture_mean', 'perimeter_mean', 'area_se')
# ('texture_mean', 'perimeter_mean', 'smoothness_se')
# ('texture_mean', 'perimeter_mean', 'compactness_se')
# ('texture_mean', 'perimeter_mean', 'concavity_se')
# ('texture_mean', 'perimeter_mean', 'concave_points_se')
# ('texture_mean', 'perimeter_mean', 'symmetry_se')
# ('texture_mean', 'perimeter_mean', 'fractal_dimension_se')
# ('texture_mean', 'perimeter_mean', 'radius_worst')
# ('texture_mean', 'perimeter_mean', 'texture_worst')
# ('texture_mean', 'perimeter_mean', 'perimeter_worst')
# ('texture_mean', 'perimeter_mean', 'area_worst')
# ('texture_mean', 'perimeter_mean', 'smoothness_worst')
# ('texture_mean', 'perimeter_mean', 'compactness_worst')
# ('texture_mean', 'perimeter_mean', 'concavity_worst')
# ('texture_mean', 'perimeter_mean', 'concave_points_worst')
# ('texture_mean', 'perimeter_mean', 'symmetry_worst')
# ('texture_mean', 'perimeter_mean', 'fractal_dimension_worst')
# ('texture_mean', 'area_mean', 'smoothness_mean')
# ('texture_mean', 'area_mean', 'compactness_mean')
# ('texture_mean', 'area_mean', 'concavity_mean')
# ('texture_mean', 'area_mean', 'concave_points_mean')
# ('texture_mean', 'area_mean', 'symmetry_mean')
# ('texture_mean', 'area_mean', 'fractal_dimension_mean')
# ('texture_mean', 'area_mean', 'radius_se')
# ('texture_mean', 'area_mean', 'texture_se')
# ('texture_mean', 'area_mean', 'perimeter_se')
# ('texture_mean', 'area_mean', 'area_se')
# ('texture_mean', 'area_mean', 'smoothness_se')
# ('texture_mean', 'area_mean', 'compactness_se')
# ('texture_mean', 'area_mean', 'concavity_se')
# ('texture_mean', 'area_mean', 'concave_points_se')
# ('texture_mean', 'area_mean', 'symmetry_se')
# ('texture_mean', 'area_mean', 'fractal_dimension_se')
# ('texture_mean', 'area_mean', 'radius_worst')
# ('texture_mean', 'area_mean', 'texture_worst')
# ('texture_mean', 'area_mean', 'perimeter_worst')
# ('texture_mean', 'area_mean', 'area_worst')
# ('texture_mean', 'area_mean', 'smoothness_worst')
# ('texture_mean', 'area_mean', 'compactness_worst')
# ('texture_mean', 'area_mean', 'concavity_worst')
# ('texture_mean', 'area_mean', 'concave_points_worst')
# ('texture_mean', 'area_mean', 'symmetry_worst')
# ('texture_mean', 'area_mean', 'fractal_dimension_worst')
# ('texture_mean', 'smoothness_mean', 'compactness_mean')
# ('texture_mean', 'smoothness_mean', 'concavity_mean')
# ('texture_mean', 'smoothness_mean', 'concave_points_mean')
# ('texture_mean', 'smoothness_mean', 'symmetry_mean')
# ('texture_mean', 'smoothness_mean', 'fractal_dimension_mean')
# ('texture_mean', 'smoothness_mean', 'radius_se')
# ('texture_mean', 'smoothness_mean', 'texture_se')
# ('texture_mean', 'smoothness_mean', 'perimeter_se')
# ('texture_mean', 'smoothness_mean', 'area_se')
# ('texture_mean', 'smoothness_mean', 'smoothness_se')
# ('texture_mean', 'smoothness_mean', 'compactness_se')
# ('texture_mean', 'smoothness_mean', 'concavity_se')
# ('texture_mean', 'smoothness_mean', 'concave_points_se')
# ('texture_mean', 'smoothness_mean', 'symmetry_se')
# ('texture_mean', 'smoothness_mean', 'fractal_dimension_se')
# ('texture_mean', 'smoothness_mean', 'radius_worst')
# ('texture_mean', 'smoothness_mean', 'texture_worst')
# ('texture_mean', 'smoothness_mean', 'perimeter_worst')
# ('texture_mean', 'smoothness_mean', 'area_worst')
# ('texture_mean', 'smoothness_mean', 'smoothness_worst')
# ('texture_mean', 'smoothness_mean', 'compactness_worst')
# ('texture_mean', 'smoothness_mean', 'concavity_worst')
# ('texture_mean', 'smoothness_mean', 'concave_points_worst')
# ('texture_mean', 'smoothness_mean', 'symmetry_worst')
# ('texture_mean', 'smoothness_mean', 'fractal_dimension_worst')
# ('texture_mean', 'compactness_mean', 'concavity_mean')
# ('texture_mean', 'compactness_mean', 'concave_points_mean')
# ('texture_mean', 'compactness_mean', 'symmetry_mean')
# ('texture_mean', 'compactness_mean', 'fractal_dimension_mean')
# ('texture_mean', 'compactness_mean', 'radius_se')
# ('texture_mean', 'compactness_mean', 'texture_se')
# ('texture_mean', 'compactness_mean', 'perimeter_se')
# ('texture_mean', 'compactness_mean', 'area_se')
# ('texture_mean', 'compactness_mean', 'smoothness_se')
# ('texture_mean', 'compactness_mean', 'compactness_se')
# ('texture_mean', 'compactness_mean', 'concavity_se')
# ('texture_mean', 'compactness_mean', 'concave_points_se')
# ('texture_mean', 'compactness_mean', 'symmetry_se')
# ('texture_mean', 'compactness_mean', 'fractal_dimension_se')
# ('texture_mean', 'compactness_mean', 'radius_worst')
# ('texture_mean', 'compactness_mean', 'texture_worst')
# ('texture_mean', 'compactness_mean', 'perimeter_worst')
# ('texture_mean', 'compactness_mean', 'area_worst')
# ('texture_mean', 'compactness_mean', 'smoothness_worst')
# ('texture_mean', 'compactness_mean', 'compactness_worst')
# ('texture_mean', 'compactness_mean', 'concavity_worst')
# ('texture_mean', 'compactness_mean', 'concave_points_worst')
# ('texture_mean', 'compactness_mean', 'symmetry_worst')
# ('texture_mean', 'compactness_mean', 'fractal_dimension_worst')
# ('texture_mean', 'concavity_mean', 'concave_points_mean')
# ('texture_mean', 'concavity_mean', 'symmetry_mean')
# ('texture_mean', 'concavity_mean', 'fractal_dimension_mean')
# ('texture_mean', 'concavity_mean', 'radius_se')
# ('texture_mean', 'concavity_mean', 'texture_se')
# ('texture_mean', 'concavity_mean', 'perimeter_se')
# ('texture_mean', 'concavity_mean', 'area_se')
# ('texture_mean', 'concavity_mean', 'smoothness_se')
# ('texture_mean', 'concavity_mean', 'compactness_se')
# ('texture_mean', 'concavity_mean', 'concavity_se')
# ('texture_mean', 'concavity_mean', 'concave_points_se')
# ('texture_mean', 'concavity_mean', 'symmetry_se')
# ('texture_mean', 'concavity_mean', 'fractal_dimension_se')
# ('texture_mean', 'concavity_mean', 'radius_worst')
# ('texture_mean', 'concavity_mean', 'texture_worst')
# ('texture_mean', 'concavity_mean', 'perimeter_worst')
# ('texture_mean', 'concavity_mean', 'area_worst')
# ('texture_mean', 'concavity_mean', 'smoothness_worst')
# ('texture_mean', 'concavity_mean', 'compactness_worst')
# ('texture_mean', 'concavity_mean', 'concavity_worst')
# ('texture_mean', 'concavity_mean', 'concave_points_worst')
# ('texture_mean', 'concavity_mean', 'symmetry_worst')
# ('texture_mean', 'concavity_mean', 'fractal_dimension_worst')
# ('texture_mean', 'concave_points_mean', 'symmetry_mean')
# ('texture_mean', 'concave_points_mean', 'fractal_dimension_mean')
# ('texture_mean', 'concave_points_mean', 'radius_se')
# ('texture_mean', 'concave_points_mean', 'texture_se')
# ('texture_mean', 'concave_points_mean', 'perimeter_se')
# ('texture_mean', 'concave_points_mean', 'area_se')
# ('texture_mean', 'concave_points_mean', 'smoothness_se')
# ('texture_mean', 'concave_points_mean', 'compactness_se')
# ('texture_mean', 'concave_points_mean', 'concavity_se')
# ('texture_mean', 'concave_points_mean', 'concave_points_se')
# ('texture_mean', 'concave_points_mean', 'symmetry_se')
# ('texture_mean', 'concave_points_mean', 'fractal_dimension_se')
# ('texture_mean', 'concave_points_mean', 'radius_worst')
# ('texture_mean', 'concave_points_mean', 'texture_worst')
# ('texture_mean', 'concave_points_mean', 'perimeter_worst')
# ('texture_mean', 'concave_points_mean', 'area_worst')
# ('texture_mean', 'concave_points_mean', 'smoothness_worst')
# ('texture_mean', 'concave_points_mean', 'compactness_worst')
# ('texture_mean', 'concave_points_mean', 'concavity_worst')
# ('texture_mean', 'concave_points_mean', 'concave_points_worst')
# ('texture_mean', 'concave_points_mean', 'symmetry_worst')
# ('texture_mean', 'concave_points_mean', 'fractal_dimension_worst')
# ('texture_mean', 'symmetry_mean', 'fractal_dimension_mean')
# ('texture_mean', 'symmetry_mean', 'radius_se')
# ('texture_mean', 'symmetry_mean', 'texture_se')
# ('texture_mean', 'symmetry_mean', 'perimeter_se')
# ('texture_mean', 'symmetry_mean', 'area_se')
# ('texture_mean', 'symmetry_mean', 'smoothness_se')
# ('texture_mean', 'symmetry_mean', 'compactness_se')
# ('texture_mean', 'symmetry_mean', 'concavity_se')
# ('texture_mean', 'symmetry_mean', 'concave_points_se')
# ('texture_mean', 'symmetry_mean', 'symmetry_se')
# ('texture_mean', 'symmetry_mean', 'fractal_dimension_se')
# ('texture_mean', 'symmetry_mean', 'radius_worst')
# ('texture_mean', 'symmetry_mean', 'texture_worst')
# ('texture_mean', 'symmetry_mean', 'perimeter_worst')
# ('texture_mean', 'symmetry_mean', 'area_worst')
# ('texture_mean', 'symmetry_mean', 'smoothness_worst')
# ('texture_mean', 'symmetry_mean', 'compactness_worst')
# ('texture_mean', 'symmetry_mean', 'concavity_worst')
# ('texture_mean', 'symmetry_mean', 'concave_points_worst')
# ('texture_mean', 'symmetry_mean', 'symmetry_worst')
# ('texture_mean', 'symmetry_mean', 'fractal_dimension_worst')
# ('texture_mean', 'fractal_dimension_mean', 'radius_se')
# ('texture_mean', 'fractal_dimension_mean', 'texture_se')
# ('texture_mean', 'fractal_dimension_mean', 'perimeter_se')
# ('texture_mean', 'fractal_dimension_mean', 'area_se')
# ('texture_mean', 'fractal_dimension_mean', 'smoothness_se')
# ('texture_mean', 'fractal_dimension_mean', 'compactness_se')
# ('texture_mean', 'fractal_dimension_mean', 'concavity_se')
# ('texture_mean', 'fractal_dimension_mean', 'concave_points_se')
# ('texture_mean', 'fractal_dimension_mean', 'symmetry_se')
# ('texture_mean', 'fractal_dimension_mean', 'fractal_dimension_se')
# ('texture_mean', 'fractal_dimension_mean', 'radius_worst')
# ('texture_mean', 'fractal_dimension_mean', 'texture_worst')
# ('texture_mean', 'fractal_dimension_mean', 'perimeter_worst')
# ...
# ('concave_points_se', 'fractal_dimension_se', 'symmetry_worst')
# ('concave_points_se', 'fractal_dimension_se', 'fractal_dimension_worst')
# ('concave_points_se', 'radius_worst', 'texture_worst')
# ('concave_points_se', 'radius_worst', 'perimeter_worst')
# ('concave_points_se', 'radius_worst', 'area_worst')
# ('concave_points_se', 'radius_worst', 'smoothness_worst')
# ('concave_points_se', 'radius_worst', 'compactness_worst')
# ('concave_points_se', 'radius_worst', 'concavity_worst')
# ('concave_points_se', 'radius_worst', 'concave_points_worst')
# ('concave_points_se', 'radius_worst', 'symmetry_worst')
# ('concave_points_se', 'radius_worst', 'fractal_dimension_worst')
# ('concave_points_se', 'texture_worst', 'perimeter_worst')
# ('concave_points_se', 'texture_worst', 'area_worst')
# ('concave_points_se', 'texture_worst', 'smoothness_worst')
# ('concave_points_se', 'texture_worst', 'compactness_worst')
# ('concave_points_se', 'texture_worst', 'concavity_worst')
# ('concave_points_se', 'texture_worst', 'concave_points_worst')
# ('concave_points_se', 'texture_worst', 'symmetry_worst')
# ('concave_points_se', 'texture_worst', 'fractal_dimension_worst')
# ('concave_points_se', 'perimeter_worst', 'area_worst')
# ('concave_points_se', 'perimeter_worst', 'smoothness_worst')
# ('concave_points_se', 'perimeter_worst', 'compactness_worst')
# ('concave_points_se', 'perimeter_worst', 'concavity_worst')
# ('concave_points_se', 'perimeter_worst', 'concave_points_worst')
# ('concave_points_se', 'perimeter_worst', 'symmetry_worst')
# ('concave_points_se', 'perimeter_worst', 'fractal_dimension_worst')
# ('concave_points_se', 'area_worst', 'smoothness_worst')
# ('concave_points_se', 'area_worst', 'compactness_worst')
# ('concave_points_se', 'area_worst', 'concavity_worst')
# ('concave_points_se', 'area_worst', 'concave_points_worst')
# ('concave_points_se', 'area_worst', 'symmetry_worst')
# ('concave_points_se', 'area_worst', 'fractal_dimension_worst')
# ('concave_points_se', 'smoothness_worst', 'compactness_worst')
# ('concave_points_se', 'smoothness_worst', 'concavity_worst')
# ('concave_points_se', 'smoothness_worst', 'concave_points_worst')
# ('concave_points_se', 'smoothness_worst', 'symmetry_worst')
# ('concave_points_se', 'smoothness_worst', 'fractal_dimension_worst')
# ('concave_points_se', 'compactness_worst', 'concavity_worst')
# ('concave_points_se', 'compactness_worst', 'concave_points_worst')
# ('concave_points_se', 'compactness_worst', 'symmetry_worst')
# ('concave_points_se', 'compactness_worst', 'fractal_dimension_worst')
# ('concave_points_se', 'concavity_worst', 'concave_points_worst')
# ('concave_points_se', 'concavity_worst', 'symmetry_worst')
# ('concave_points_se', 'concavity_worst', 'fractal_dimension_worst')
# ('concave_points_se', 'concave_points_worst', 'symmetry_worst')
# ('concave_points_se', 'concave_points_worst', 'fractal_dimension_worst')
# ('concave_points_se', 'symmetry_worst', 'fractal_dimension_worst')
# ('symmetry_se', 'fractal_dimension_se', 'radius_worst')
# ('symmetry_se', 'fractal_dimension_se', 'texture_worst')
# ('symmetry_se', 'fractal_dimension_se', 'perimeter_worst')
# ('symmetry_se', 'fractal_dimension_se', 'area_worst')
# ('symmetry_se', 'fractal_dimension_se', 'smoothness_worst')
# ('symmetry_se', 'fractal_dimension_se', 'compactness_worst')
# ('symmetry_se', 'fractal_dimension_se', 'concavity_worst')
# ('symmetry_se', 'fractal_dimension_se', 'concave_points_worst')
# ('symmetry_se', 'fractal_dimension_se', 'symmetry_worst')
# ('symmetry_se', 'fractal_dimension_se', 'fractal_dimension_worst')
# ('symmetry_se', 'radius_worst', 'texture_worst')
# ('symmetry_se', 'radius_worst', 'perimeter_worst')
# ('symmetry_se', 'radius_worst', 'area_worst')
# ('symmetry_se', 'radius_worst', 'smoothness_worst')
# ('symmetry_se', 'radius_worst', 'compactness_worst')
# ('symmetry_se', 'radius_worst', 'concavity_worst')
# ('symmetry_se', 'radius_worst', 'concave_points_worst')
# ('symmetry_se', 'radius_worst', 'symmetry_worst')
# ('symmetry_se', 'radius_worst', 'fractal_dimension_worst')
# ('symmetry_se', 'texture_worst', 'perimeter_worst')
# ('symmetry_se', 'texture_worst', 'area_worst')
# ('symmetry_se', 'texture_worst', 'smoothness_worst')
# ('symmetry_se', 'texture_worst', 'compactness_worst')
# ('symmetry_se', 'texture_worst', 'concavity_worst')
# ('symmetry_se', 'texture_worst', 'concave_points_worst')
# ('symmetry_se', 'texture_worst', 'symmetry_worst')
# ('symmetry_se', 'texture_worst', 'fractal_dimension_worst')
# ('symmetry_se', 'perimeter_worst', 'area_worst')
# ('symmetry_se', 'perimeter_worst', 'smoothness_worst')
# ('symmetry_se', 'perimeter_worst', 'compactness_worst')
# ('symmetry_se', 'perimeter_worst', 'concavity_worst')
# ('symmetry_se', 'perimeter_worst', 'concave_points_worst')
# ('symmetry_se', 'perimeter_worst', 'symmetry_worst')
# ('symmetry_se', 'perimeter_worst', 'fractal_dimension_worst')
# ('symmetry_se', 'area_worst', 'smoothness_worst')
# ('symmetry_se', 'area_worst', 'compactness_worst')
# ('symmetry_se', 'area_worst', 'concavity_worst')
# ('symmetry_se', 'area_worst', 'concave_points_worst')
# ('symmetry_se', 'area_worst', 'symmetry_worst')
# ('symmetry_se', 'area_worst', 'fractal_dimension_worst')
# ('symmetry_se', 'smoothness_worst', 'compactness_worst')
# ('symmetry_se', 'smoothness_worst', 'concavity_worst')
# ('symmetry_se', 'smoothness_worst', 'concave_points_worst')
# ('symmetry_se', 'smoothness_worst', 'symmetry_worst')
# ('symmetry_se', 'smoothness_worst', 'fractal_dimension_worst')
# ('symmetry_se', 'compactness_worst', 'concavity_worst')
# ('symmetry_se', 'compactness_worst', 'concave_points_worst')
# ('symmetry_se', 'compactness_worst', 'symmetry_worst')
# ('symmetry_se', 'compactness_worst', 'fractal_dimension_worst')
# ('symmetry_se', 'concavity_worst', 'concave_points_worst')
# ('symmetry_se', 'concavity_worst', 'symmetry_worst')
# ('symmetry_se', 'concavity_worst', 'fractal_dimension_worst')
# ('symmetry_se', 'concave_points_worst', 'symmetry_worst')
# ('symmetry_se', 'concave_points_worst', 'fractal_dimension_worst')
# ('symmetry_se', 'symmetry_worst', 'fractal_dimension_worst')
# ('fractal_dimension_se', 'radius_worst', 'texture_worst')
# ('fractal_dimension_se', 'radius_worst', 'perimeter_worst')
# ('fractal_dimension_se', 'radius_worst', 'area_worst')
# ('fractal_dimension_se', 'radius_worst', 'smoothness_worst')
# ('fractal_dimension_se', 'radius_worst', 'compactness_worst')
# ('fractal_dimension_se', 'radius_worst', 'concavity_worst')
# ('fractal_dimension_se', 'radius_worst', 'concave_points_worst')
# ('fractal_dimension_se', 'radius_worst', 'symmetry_worst')
# ('fractal_dimension_se', 'radius_worst', 'fractal_dimension_worst')
# ('fractal_dimension_se', 'texture_worst', 'perimeter_worst')
# ('fractal_dimension_se', 'texture_worst', 'area_worst')
# ('fractal_dimension_se', 'texture_worst', 'smoothness_worst')
# ('fractal_dimension_se', 'texture_worst', 'compactness_worst')
# ('fractal_dimension_se', 'texture_worst', 'concavity_worst')
# ('fractal_dimension_se', 'texture_worst', 'concave_points_worst')
# ('fractal_dimension_se', 'texture_worst', 'symmetry_worst')
# ('fractal_dimension_se', 'texture_worst', 'fractal_dimension_worst')
# ('fractal_dimension_se', 'perimeter_worst', 'area_worst')
# ('fractal_dimension_se', 'perimeter_worst', 'smoothness_worst')
# ('fractal_dimension_se', 'perimeter_worst', 'compactness_worst')
# ('fractal_dimension_se', 'perimeter_worst', 'concavity_worst')
# ('fractal_dimension_se', 'perimeter_worst', 'concave_points_worst')
# ('fractal_dimension_se', 'perimeter_worst', 'symmetry_worst')
# ('fractal_dimension_se', 'perimeter_worst', 'fractal_dimension_worst')
# ('fractal_dimension_se', 'area_worst', 'smoothness_worst')
# ('fractal_dimension_se', 'area_worst', 'compactness_worst')
# ('fractal_dimension_se', 'area_worst', 'concavity_worst')
# ('fractal_dimension_se', 'area_worst', 'concave_points_worst')
# ('fractal_dimension_se', 'area_worst', 'symmetry_worst')
# ('fractal_dimension_se', 'area_worst', 'fractal_dimension_worst')
# ('fractal_dimension_se', 'smoothness_worst', 'compactness_worst')
# ('fractal_dimension_se', 'smoothness_worst', 'concavity_worst')
# ('fractal_dimension_se', 'smoothness_worst', 'concave_points_worst')
# ('fractal_dimension_se', 'smoothness_worst', 'symmetry_worst')
# ('fractal_dimension_se', 'smoothness_worst', 'fractal_dimension_worst')
# ('fractal_dimension_se', 'compactness_worst', 'concavity_worst')
# ('fractal_dimension_se', 'compactness_worst', 'concave_points_worst')
# ('fractal_dimension_se', 'compactness_worst', 'symmetry_worst')
# ('fractal_dimension_se', 'compactness_worst', 'fractal_dimension_worst')
# ('fractal_dimension_se', 'concavity_worst', 'concave_points_worst')
# ('fractal_dimension_se', 'concavity_worst', 'symmetry_worst')
# ('fractal_dimension_se', 'concavity_worst', 'fractal_dimension_worst')
# ('fractal_dimension_se', 'concave_points_worst', 'symmetry_worst')
# ('fractal_dimension_se', 'concave_points_worst', 'fractal_dimension_worst')
# ('fractal_dimension_se', 'symmetry_worst', 'fractal_dimension_worst')
# ('radius_worst', 'texture_worst', 'perimeter_worst')
# ('radius_worst', 'texture_worst', 'area_worst')
# ('radius_worst', 'texture_worst', 'smoothness_worst')
# ('radius_worst', 'texture_worst', 'compactness_worst')
# ('radius_worst', 'texture_worst', 'concavity_worst')
# ('radius_worst', 'texture_worst', 'concave_points_worst')
# ('radius_worst', 'texture_worst', 'symmetry_worst')
# ('radius_worst', 'texture_worst', 'fractal_dimension_worst')
# ('radius_worst', 'perimeter_worst', 'area_worst')
# ('radius_worst', 'perimeter_worst', 'smoothness_worst')
# ('radius_worst', 'perimeter_worst', 'compactness_worst')
# ('radius_worst', 'perimeter_worst', 'concavity_worst')
# ('radius_worst', 'perimeter_worst', 'concave_points_worst')
# ('radius_worst', 'perimeter_worst', 'symmetry_worst')
# ('radius_worst', 'perimeter_worst', 'fractal_dimension_worst')
# ('radius_worst', 'area_worst', 'smoothness_worst')
# ('radius_worst', 'area_worst', 'compactness_worst')
# ('radius_worst', 'area_worst', 'concavity_worst')
# ('radius_worst', 'area_worst', 'concave_points_worst')
# ('radius_worst', 'area_worst', 'symmetry_worst')
# ('radius_worst', 'area_worst', 'fractal_dimension_worst')
# ('radius_worst', 'smoothness_worst', 'compactness_worst')
# ('radius_worst', 'smoothness_worst', 'concavity_worst')
# ('radius_worst', 'smoothness_worst', 'concave_points_worst')
# ('radius_worst', 'smoothness_worst', 'symmetry_worst')
# ('radius_worst', 'smoothness_worst', 'fractal_dimension_worst')
# ('radius_worst', 'compactness_worst', 'concavity_worst')
# ('radius_worst', 'compactness_worst', 'concave_points_worst')
# ('radius_worst', 'compactness_worst', 'symmetry_worst')
# ('radius_worst', 'compactness_worst', 'fractal_dimension_worst')
# ('radius_worst', 'concavity_worst', 'concave_points_worst')
# ('radius_worst', 'concavity_worst', 'symmetry_worst')
# ('radius_worst', 'concavity_worst', 'fractal_dimension_worst')
# ('radius_worst', 'concave_points_worst', 'symmetry_worst')
# ('radius_worst', 'concave_points_worst', 'fractal_dimension_worst')
# ('radius_worst', 'symmetry_worst', 'fractal_dimension_worst')
# ('texture_worst', 'perimeter_worst', 'area_worst')
# ('texture_worst', 'perimeter_worst', 'smoothness_worst')
# ('texture_worst', 'perimeter_worst', 'compactness_worst')
# ('texture_worst', 'perimeter_worst', 'concavity_worst')
# ('texture_worst', 'perimeter_worst', 'concave_points_worst')
# ('texture_worst', 'perimeter_worst', 'symmetry_worst')
# ('texture_worst', 'perimeter_worst', 'fractal_dimension_worst')
# ('texture_worst', 'area_worst', 'smoothness_worst')
# ('texture_worst', 'area_worst', 'compactness_worst')
# ('texture_worst', 'area_worst', 'concavity_worst')
# ('texture_worst', 'area_worst', 'concave_points_worst')
# ('texture_worst', 'area_worst', 'symmetry_worst')
# ('texture_worst', 'area_worst', 'fractal_dimension_worst')
# ('texture_worst', 'smoothness_worst', 'compactness_worst')
# ('texture_worst', 'smoothness_worst', 'concavity_worst')
# ('texture_worst', 'smoothness_worst', 'concave_points_worst')
# ('texture_worst', 'smoothness_worst', 'symmetry_worst')
# ('texture_worst', 'smoothness_worst', 'fractal_dimension_worst')
# ('texture_worst', 'compactness_worst', 'concavity_worst')
# ('texture_worst', 'compactness_worst', 'concave_points_worst')
# ('texture_worst', 'compactness_worst', 'symmetry_worst')
# ('texture_worst', 'compactness_worst', 'fractal_dimension_worst')
# ('texture_worst', 'concavity_worst', 'concave_points_worst')
# ('texture_worst', 'concavity_worst', 'symmetry_worst')
# ('texture_worst', 'concavity_worst', 'fractal_dimension_worst')
# ('texture_worst', 'concave_points_worst', 'symmetry_worst')
# ('texture_worst', 'concave_points_worst', 'fractal_dimension_worst')
# ('texture_worst', 'symmetry_worst', 'fractal_dimension_worst')
# ('perimeter_worst', 'area_worst', 'smoothness_worst')
# ('perimeter_worst', 'area_worst', 'compactness_worst')
# ('perimeter_worst', 'area_worst', 'concavity_worst')
# ('perimeter_worst', 'area_worst', 'concave_points_worst')
# ('perimeter_worst', 'area_worst', 'symmetry_worst')
# ('perimeter_worst', 'area_worst', 'fractal_dimension_worst')
# ('perimeter_worst', 'smoothness_worst', 'compactness_worst')
# ('perimeter_worst', 'smoothness_worst', 'concavity_worst')
# ('perimeter_worst', 'smoothness_worst', 'concave_points_worst')
# ('perimeter_worst', 'smoothness_worst', 'symmetry_worst')
# ('perimeter_worst', 'smoothness_worst', 'fractal_dimension_worst')
# ('perimeter_worst', 'compactness_worst', 'concavity_worst')
# ('perimeter_worst', 'compactness_worst', 'concave_points_worst')
# ('perimeter_worst', 'compactness_worst', 'symmetry_worst')
# ('perimeter_worst', 'compactness_worst', 'fractal_dimension_worst')
# ('perimeter_worst', 'concavity_worst', 'concave_points_worst')
# ('perimeter_worst', 'concavity_worst', 'symmetry_worst')
# ('perimeter_worst', 'concavity_worst', 'fractal_dimension_worst')
# ('perimeter_worst', 'concave_points_worst', 'symmetry_worst')
# ('perimeter_worst', 'concave_points_worst', 'fractal_dimension_worst')
# ('perimeter_worst', 'symmetry_worst', 'fractal_dimension_worst')
# ('area_worst', 'smoothness_worst', 'compactness_worst')
# ('area_worst', 'smoothness_worst', 'concavity_worst')
# ('area_worst', 'smoothness_worst', 'concave_points_worst')
# ('area_worst', 'smoothness_worst', 'symmetry_worst')
# ('area_worst', 'smoothness_worst', 'fractal_dimension_worst')
# ('area_worst', 'compactness_worst', 'concavity_worst')
# ('area_worst', 'compactness_worst', 'concave_points_worst')
# ('area_worst', 'compactness_worst', 'symmetry_worst')
# ('area_worst', 'compactness_worst', 'fractal_dimension_worst')
# ('area_worst', 'concavity_worst', 'concave_points_worst')
# ('area_worst', 'concavity_worst', 'symmetry_worst')
# ('area_worst', 'concavity_worst', 'fractal_dimension_worst')
# ('area_worst', 'concave_points_worst', 'symmetry_worst')
# ('area_worst', 'concave_points_worst', 'fractal_dimension_worst')
# ('area_worst', 'symmetry_worst', 'fractal_dimension_worst')
# ('smoothness_worst', 'compactness_worst', 'concavity_worst')
# ('smoothness_worst', 'compactness_worst', 'concave_points_worst')
# ('smoothness_worst', 'compactness_worst', 'symmetry_worst')
# ('smoothness_worst', 'compactness_worst', 'fractal_dimension_worst')
# ('smoothness_worst', 'concavity_worst', 'concave_points_worst')
# ('smoothness_worst', 'concavity_worst', 'symmetry_worst')
# ('smoothness_worst', 'concavity_worst', 'fractal_dimension_worst')
# ('smoothness_worst', 'concave_points_worst', 'symmetry_worst')
# ('smoothness_worst', 'concave_points_worst', 'fractal_dimension_worst')
# ('smoothness_worst', 'symmetry_worst', 'fractal_dimension_worst')
# ('compactness_worst', 'concavity_worst', 'concave_points_worst')
# ('compactness_worst', 'concavity_worst', 'symmetry_worst')
# ('compactness_worst', 'concavity_worst', 'fractal_dimension_worst')
# ('compactness_worst', 'concave_points_worst', 'symmetry_worst')
# ('compactness_worst', 'concave_points_worst', 'fractal_dimension_worst')
# ('compactness_worst', 'symmetry_worst', 'fractal_dimension_worst')
# ('concavity_worst', 'concave_points_worst', 'symmetry_worst')
# ('concavity_worst', 'concave_points_worst', 'fractal_dimension_worst')
# ('concavity_worst', 'symmetry_worst', 'fractal_dimension_worst')
# ('concave_points_worst', 'symmetry_worst', 'fractal_dimension_worst')

# %%
for i in itertools.combinations(df.columns, 1):
    print(i)
# Out:
# ('radius_mean',)
# ('texture_mean',)
# ('perimeter_mean',)
# ('area_mean',)
# ('smoothness_mean',)
# ('compactness_mean',)
# ('concavity_mean',)
# ('concave_points_mean',)
# ('symmetry_mean',)
# ('fractal_dimension_mean',)
# ('radius_se',)
# ('texture_se',)
# ('perimeter_se',)
# ('area_se',)
# ('smoothness_se',)
# ('compactness_se',)
# ('concavity_se',)
# ('concave_points_se',)
# ('symmetry_se',)
# ('fractal_dimension_se',)
# ('radius_worst',)
# ('texture_worst',)
# ('perimeter_worst',)
# ('area_worst',)
# ('smoothness_worst',)
# ('compactness_worst',)
# ('concavity_worst',)
# ('concave_points_worst',)
# ('symmetry_worst',)
# ('fractal_dimension_worst',)
